# %% [markdown]
# #Pre-Processing

# %%
import pandas as pd
import numpy as np
import matplotlib as mlp

# %%
data = pd.read_csv("testing.csv")
data.head()
# Out:
#    Sr.no            name                                        ingredients  \
# 0      1      Balu shahi                    Maida flour, yogurt, oil, sugar
# 1      2          Boondi                            Gram flour, ghee, sugar
# 2      3  Gajar ka halwa       Carrots, milk, sugar, ghee, cashews, raisins
# 3      4          Ghevar  Flour, ghee, kewra, milk, clarified butter, su...
# 4      5     Gulab jamun  Milk powder, plain flour, baking powder, ghee,...
#
#          diet  prep_time  cook_time  Total_time flavor_profile   course  \
# 0  vegetarian         45         25          70          sweet  dessert
# 1  vegetarian         80         30         110          sweet  dessert
# 2  vegetarian         15         60          75          sweet  dessert
# 3  vegetarian         15         30          45          sweet  dessert
# 4  vegetarian         15         40          55          sweet  dessert
#
#          state region
# 0  West Bengal   East
# 1    Rajasthan   West
# ...

# %%
df1 = data.filter(['flavor_profile' , 'region'])

# %%
df1
# Out:
#     flavor_profile      region
# 0            sweet        East
# 1            sweet        West
# 2            sweet       North
# 3            sweet        West
# 4            sweet        East
# ..             ...         ...
# 220          spicy        East
# 221          spicy        East
# 222          sweet  North East
# 223          sweet        West
# 224          sweet     Central
#
# [225 rows x 2 columns]

# %%
df1 = df1[df1['flavor_profile']=='spicy']
df1.head()
# Out:
#    flavor_profile      region
# 62          spicy  North East
# 64          spicy  North East
# 65          spicy       North
# 66          spicy       North
# 67          spicy       North

# %%
df1= pd.get_dummies(df1,columns=['region'])

# %%
final_df = pd.DataFrame(columns=['flavor_profile','North'])
final_df['flavor_profile'] = df1['flavor_profile']
final_df['North']=df1['region_North']
final_df
# Out:
#     flavor_profile  North
# 62           spicy      0
# 64           spicy      0
# 65           spicy      1
# 66           spicy      1
# 67           spicy      1
# ..             ...    ...
# 211          spicy      0
# 214          spicy      0
# 216          spicy      0
# 220          spicy      0
# 221          spicy      0
#
# [116 rows x 2 columns]

# %%
final_df.to_csv('Question1.csv',index=False)

# %%
data
# Out:
#      Sr.no               name  \
# 0        1         Balu shahi
# 1        2             Boondi
# 2        3     Gajar ka halwa
# 3        4             Ghevar
# 4        5        Gulab jamun
# ..     ...                ...
# 220    223  Prawn malai curry
# 221    224             Shukto
# 222    225          Til Pitha
# 223    226            Bebinca
# 224    227          Mawa Bati
#
#                                            ingredients            diet  \
# 0                      Maida flour, yogurt, oil, sugar      vegetarian
# 1                              Gram flour, ghee, sugar      vegetarian
# 2         Carrots, milk, sugar, ghee, cashews, raisins      vegetarian
# 3    Flour, ghee, kewra, milk, clarified butter, su...      vegetarian
# 4    Milk powder, plain flour, baking powder, ghee,...      vegetarian
# ..                                                 ...             ...
# 220      Coconut milk, prawns, garlic, turmeric, sugar  non vegetarian
# ...

# %%
df2 = data[data['course']=="main course"]

# %%
df2 = df2.drop(['Sr.no','name','ingredients','diet','prep_time','cook_time','flavor_profile','course','region'],axis=1)
df2
# Out:
#      Total_time        state
# 44          240    Karnataka
# 62           50        Assam
# 64           20     Nagaland
# 65           30       Punjab
# 66           25       Punjab
# ..          ...          ...
# 217          45  West Bengal
# 218          40  West Bengal
# 219          30        Assam
# 220          65  West Bengal
# 221          30  West Bengal
#
# [110 rows x 2 columns]

# %%
df2.drop(df2[df2['state']=="-1"].index , inplace = True)

# %%
df2.loc[df2['state']==-1]
# Out:
# Empty DataFrame
# Columns: [Total_time, state]
# Index: []

# %%
df2.to_csv('question3.csv',index=False)
